# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import keras
from keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib.pyplot as plt
from google.cloud import bigquery

# %%
client = bigquery.Client()
dollar_bars = client.query(
    """
  SELECT date, open, high, low, close, volume FROM chemackana-project.ticks_test.ADA_DOLLAR_BARS"""
  ).to_dataframe()

# %%
dollar_bars.set_index("date", inplace = True)
dollar_bars = dollar_bars.sort_index()

# %%
dollar_bars
# Out:
#                          open      high       low     close        volume
# date
# 2019-01-16 02:04:31  0.040319  0.074000  0.039000  0.042583  9.787693e+07
# 2019-01-23 11:33:23  0.042419  0.046266  0.041167  0.043663  1.025501e+08
# 2019-01-28 04:41:26  0.043648  0.043958  0.038341  0.039013  1.060277e+08
# 2019-02-01 17:22:11  0.039040  0.040496  0.035778  0.038628  1.166936e+08
# 2019-02-05 16:46:59  0.038631  0.039711  0.037030  0.037837  1.166463e+08
# ...                       ...       ...       ...       ...           ...
# 2021-06-05 21:38:07  1.625700  1.627400  1.600300  1.615000  2.755405e+06
# 2021-06-05 21:42:52  1.615000  1.631256  1.614900  1.616988  2.762643e+06
# 2021-06-05 21:52:32  1.616398  1.628800  1.606435  1.618347  2.763708e+06
# 2021-06-05 22:25:17  1.617669  1.654700  1.614900  1.648600  2.744229e+06
# 2021-06-05 23:24:28  1.648600  1.659000  1.626567  1.651500  2.720482e+06
#
# [11763 rows x 5 columns]

# %%
close_data = dollar_bars['close'].values
close_data = close_data.reshape((-1,1))

split_percent_oot = 0.90
split_percent_oob = 0.80
split_1 = int(split_percent_oot*len(close_data))


close_train = close_data[:split_1]
close_test_oot = close_data[split_1:]
split_2 = int(split_percent_oob*len(close_train))
close_train = close_data[:split_2]
close_test_oob = close_data[split_2:split_1]

date_train = dollar_bars.index[:split_2]
date_test_oob = dollar_bars.index[split_2:split_1]
date_test_oot = dollar_bars.index[split_1:]

print(len(close_train))
print(len(close_test_oob))
print(len(close_test_oot))
# Out:
# 8468
# 2118
# 1177

# %%
look_back = 15

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test_oob, close_test_oob, length=look_back, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(
    LSTM(10,
        activation='relu',
        input_shape=(look_back,1))
)
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

num_epochs = 100
model.fit_generator(train_generator, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/100
# /opt/conda/miniconda3/lib/python3.8/site-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 423/423 [==============================] - 4s 6ms/step - loss: 1.1337
# Epoch 2/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0384
# Epoch 3/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0126
# Epoch 4/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0110
# Epoch 5/100
# 423/423 [==============================] - 3s 6ms/step - loss: 0.0088
# Epoch 6/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0079
# Epoch 7/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0064
# Epoch 8/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0046
# Epoch 9/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0046
# Epoch 10/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0031
# Epoch 11/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0026
# Epoch 12/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0019
# Epoch 13/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0019
# Epoch 14/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.9122e-04
# Epoch 15/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.8722e-04
# Epoch 16/100
# 423/423 [==============================] - 2s 6ms/step - loss: 0.0012
# Epoch 17/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.9135e-04
# Epoch 18/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.0414e-04
# Epoch 19/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.8646e-04
# Epoch 20/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.6274e-04
# Epoch 21/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.3836e-04
# Epoch 22/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.2597e-04
# Epoch 23/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.5508e-04
# Epoch 24/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.4060e-04
# Epoch 25/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.4613e-04
# Epoch 26/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.0308e-04
# Epoch 27/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.5236e-04
# Epoch 28/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.3963e-04
# Epoch 29/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.8193e-04
# Epoch 30/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.8495e-04
# Epoch 31/100
# 423/423 [==============================] - 2s 6ms/step - loss: 9.8283e-04
# Epoch 32/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.8286e-04
# Epoch 33/100
# 423/423 [==============================] - 2s 5ms/step - loss: 5.7688e-04
# Epoch 34/100
# 423/423 [==============================] - 2s 6ms/step - loss: 8.7514e-04
# Epoch 35/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.7810e-04
# Epoch 36/100
# 423/423 [==============================] - 2s 6ms/step - loss: 8.9677e-04
# Epoch 37/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.1137e-04
# Epoch 38/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.7918e-04
# Epoch 39/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.5540e-04
# Epoch 40/100
# 423/423 [==============================] - 2s 6ms/step - loss: 8.3560e-04
# Epoch 41/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.5750e-04
# Epoch 42/100
# 423/423 [==============================] - 2s 5ms/step - loss: 4.7552e-04
# Epoch 43/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.2354e-04
# Epoch 44/100
# 423/423 [==============================] - 2s 5ms/step - loss: 6.6181e-04
# Epoch 45/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.7176e-04
# Epoch 46/100
# 423/423 [==============================] - 2s 6ms/step - loss: 7.3025e-04
# Epoch 47/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.6141e-04
# Epoch 48/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.9325e-04
# Epoch 49/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.7546e-04
# Epoch 50/100
# 423/423 [==============================] - 2s 5ms/step - loss: 6.4547e-04
# Epoch 51/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.3204e-04
# Epoch 52/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.3156e-04
# Epoch 53/100
# 423/423 [==============================] - 2s 5ms/step - loss: 4.8979e-04
# Epoch 54/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.4762e-04
# Epoch 55/100
# 423/423 [==============================] - 2s 6ms/step - loss: 5.4265e-04
# Epoch 56/100
# 423/423 [==============================] - 2s 5ms/step - loss: 6.2261e-04
# Epoch 57/100
# 423/423 [==============================] - 2s 5ms/step - loss: 4.7135e-04
# Epoch 58/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.8748e-04
# Epoch 59/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.4416e-04
# Epoch 60/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.6717e-04
# Epoch 61/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.4819e-04
# Epoch 62/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.8433e-04
# Epoch 63/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.8082e-04
# Epoch 64/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.4988e-04
# Epoch 65/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.2982e-04
# Epoch 66/100
# 423/423 [==============================] - 2s 5ms/step - loss: 5.4589e-04
# Epoch 67/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.5495e-04
# Epoch 68/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.5508e-04
# Epoch 69/100
# 423/423 [==============================] - 3s 6ms/step - loss: 4.0814e-04
# Epoch 70/100
# 423/423 [==============================] - 3s 6ms/step - loss: 4.8426e-04
# Epoch 71/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.0645e-04
# Epoch 72/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.5996e-04
# Epoch 73/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.8396e-04
# Epoch 74/100
# 423/423 [==============================] - 2s 5ms/step - loss: 3.5418e-04
# Epoch 75/100
# 423/423 [==============================] - 2s 5ms/step - loss: 3.6972e-04
# Epoch 76/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.7776e-04
# Epoch 77/100
# 423/423 [==============================] - 2s 5ms/step - loss: 3.9713e-04
# Epoch 78/100
# 423/423 [==============================] - 2s 5ms/step - loss: 5.2133e-04
# Epoch 79/100
# 423/423 [==============================] - 2s 5ms/step - loss: 3.7648e-04
# Epoch 80/100
# 423/423 [==============================] - 2s 5ms/step - loss: 3.1038e-04
# Epoch 81/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.6073e-04
# Epoch 82/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.3968e-04
# Epoch 83/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.2692e-04
# Epoch 84/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.5655e-04
# Epoch 85/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.2806e-04
# Epoch 86/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.2503e-04
# Epoch 87/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.3609e-04
# Epoch 88/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.3876e-04
# Epoch 89/100
# 423/423 [==============================] - 2s 6ms/step - loss: 6.7805e-04
# Epoch 90/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.5683e-04
# Epoch 91/100
# 423/423 [==============================] - 2s 5ms/step - loss: 4.5630e-04
# Epoch 92/100
# 423/423 [==============================] - 2s 5ms/step - loss: 3.0431e-04
# Epoch 93/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.1588e-04
# Epoch 94/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.0004e-04
# Epoch 95/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.7059e-04
# Epoch 96/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.4056e-04
# Epoch 97/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.5137e-04
# Epoch 98/100
# 423/423 [==============================] - 2s 6ms/step - loss: 4.3397e-04
# Epoch 99/100
# 423/423 [==============================] - 2s 6ms/step - loss: 2.7208e-04
# Epoch 100/100
# 423/423 [==============================] - 2s 6ms/step - loss: 3.9467e-04

# %%
preds=model.predict(test_generator)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(preds, close_test_oob[15:])
# Out:
# 0.02667041598861629

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [CAD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)

# %%
line_plot(close_test_oob, preds, 'actual', 'prediction', lw=3)

# %%
test_generator_oot = TimeseriesGenerator(close_test_oot, close_test_oot, length=look_back, batch_size=1)

# %%
preds_oot=model.predict(test_generator_oot)

# %%
mean_absolute_error(preds_oot, close_test_oot[15:])
# Out:
# 0.019512324397956728

# %%
line_plot(close_test_oot, preds_oot, 'actual', 'prediction', lw=3)

# %%
close_data = close_data.reshape((-1))

def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = dollar_bars.index.values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 500
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)

# %%
oot_forecast=np.concatenate([preds_oot, forecast.reshape(501,1)])

# %%
len(close_test_oot)
# Out:
# 1177

# %%
len(oot_forecast)
# Out:
# 1663

# %%
line_plot(close_test_oot, oot_forecast, 'actual', 'prediction', lw=1)

# %%
dollar_bars.index = pd.to_datetime(dollar_bars.index)

# %%
oot_df = pd.DataFrame({'date': date_test_oot, 'close': close_test_oot.reshape(-1)})

# %%
from datetime import timedelta, date

current_date = dollar_bars.index.max()
future_date = dollar_bars.index.max() + timedelta(days = 10)

start = pd.Timestamp(current_date)
end = pd.Timestamp(future_date)
t = np.linspace(start.value, end.value, 501)
t = pd.to_datetime(t)

# %%
forecast_df =  pd.DataFrame({'date': t, 'close': forecast})

# %%
res_df = pd.concat([oot_df[-100:],forecast_df])

# %%
res_df.to_csv("/home/ts_model/ada_forecast.csv", index=False)

# %%
from google.cloud import storage
#@bucket_name: nombre del bucket
#@source_path: ruta al archivo local
#@destination_path: nombre del archivo como se va a guardar en bucket
def uploadToBucket(bucket_name, source_path, destination_path):
    try:
        client = storage.Client()
        bucket = client.get_bucket(bucket_name)
        blob = bucket.blob(destination_path)
        blob.upload_from_filename(source_path)

    except Exception as e:
        print("Error {er}".format(str(e)))

# %%
uploadToBucket('bd_predictions','/home/ts_model/ada_forecast.csv','ada_forecast.csv')
