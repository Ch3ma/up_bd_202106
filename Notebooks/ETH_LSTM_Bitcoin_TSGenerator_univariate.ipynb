# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import keras
from keras.preprocessing.sequence import TimeseriesGenerator
import matplotlib.pyplot as plt
from google.cloud import bigquery

# %%
client = bigquery.Client()
dollar_bars = client.query(
    """
  SELECT date, open, high, low, close, volume FROM chemackana-project.ticks_test.ETH_DOLLAR_BARS"""
  ).to_dataframe()

# %%
dollar_bars.set_index("date", inplace = True)
dollar_bars = dollar_bars.sort_index()

# %%
dollar_bars
# Out:
#                            open         high      low       close  \
# date
# 2019-01-01 13:56:06   130.66000   143.440000   129.50   140.84000
# 2019-01-01 21:07:24   140.85000   148.151924   130.82   138.42000
# 2019-01-02 07:20:22   144.41000   149.400000   135.06   142.63999
# 2019-01-02 12:57:18   142.63999   155.810000   142.49   148.63000
# 2019-01-02 16:54:26   148.17000   160.820000   147.43   157.60000
# ...                         ...          ...      ...         ...
# 2021-06-06 13:19:42  2708.34000  2729.030000  2666.21  2666.80000
# 2021-06-06 15:20:21  2667.50000  2733.960000  2653.30  2720.88000
# 2021-06-06 17:54:04  2720.14000  2738.570553  2683.94  2694.65000
# 2021-06-06 20:56:20  2694.62000  2709.100000  2666.20  2703.01000
# 2021-06-06 22:36:40  2701.70000  2719.400000  2671.00  2678.28000
#
#                             volume
# date
# 2019-01-01 13:56:06  297439.939532
# 2019-01-01 21:07:24  289159.297022
# 2019-01-02 07:20:22  283370.320293
# 2019-01-02 12:57:18  269910.837161
# 2019-01-02 16:54:26  262522.102513
# ...                            ...
# 2021-06-06 13:19:42   14981.312446
# 2021-06-06 15:20:21   15021.305206
# 2021-06-06 17:54:04   14891.130212
# 2021-06-06 20:56:20   15054.797968
# 2021-06-06 22:36:40   14967.980871
#
# [10520 rows x 5 columns]

# %%
close_data = dollar_bars['close'].values
close_data = close_data.reshape((-1,1))

split_percent_oot = 0.90
split_percent_oob = 0.80
split_1 = int(split_percent_oot*len(close_data))


close_train = close_data[:split_1]
close_test_oot = close_data[split_1:]
split_2 = int(split_percent_oob*len(close_train))
close_train = close_data[:split_2]
close_test_oob = close_data[split_2:split_1]

date_train = dollar_bars.index[:split_2]
date_test_oob = dollar_bars.index[split_2:split_1]
date_test_oot = dollar_bars.index[split_1:]

print(len(close_train))
print(len(close_test_oob))
print(len(close_test_oot))
# Out:
# 7574
# 1894
# 1052

# %%
look_back = 15

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test_oob, close_test_oob, length=look_back, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(
    LSTM(10,
        activation='relu',
        input_shape=(look_back,1))
)
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

num_epochs = 100
model.fit_generator(train_generator, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/100
# /opt/conda/miniconda3/lib/python3.8/site-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 378/378 [==============================] - 21s 6ms/step - loss: 1459441.2705
# Epoch 2/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1621770.6954
# Epoch 3/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1798270.7688
# Epoch 4/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1687284.1906
# Epoch 5/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1666871.3881
# Epoch 6/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1626393.2652
# Epoch 7/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1520227.0724
# Epoch 8/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1655171.4612
# Epoch 9/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1689084.5137
# Epoch 10/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1755025.0313
# Epoch 11/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1739919.5987
# Epoch 12/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1583814.2817
# Epoch 13/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1602429.2332
# Epoch 14/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1809628.7073
# Epoch 15/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1797915.6430
# Epoch 16/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1701023.9944
# Epoch 17/100
# 378/378 [==============================] - 2s 6ms/step - loss: 301325.9627
# Epoch 18/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2000.1945
# Epoch 19/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1986.0746
# Epoch 20/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1902.5921
# Epoch 21/100
# 378/378 [==============================] - 2s 6ms/step - loss: 5944.9422
# Epoch 22/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2195.2857
# Epoch 23/100
# 378/378 [==============================] - 2s 6ms/step - loss: 3400.3705
# Epoch 24/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2438.0260
# Epoch 25/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1980.6002
# Epoch 26/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2225.2734
# Epoch 27/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1822.4831
# Epoch 28/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2400.3723
# Epoch 29/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2118.1292
# Epoch 30/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1933.0723
# Epoch 31/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2020.0924
# Epoch 32/100
# 378/378 [==============================] - 2s 6ms/step - loss: 5241.6937
# Epoch 33/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2083.2137
# Epoch 34/100
# 378/378 [==============================] - 2s 6ms/step - loss: 3448.9149
# Epoch 35/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1896.7338
# Epoch 36/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2165.6929
# Epoch 37/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1803.7027
# Epoch 38/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2826.5014
# Epoch 39/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1910.3135
# Epoch 40/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1879.5678
# Epoch 41/100
# 378/378 [==============================] - 2s 6ms/step - loss: 3088.1106
# Epoch 42/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1884.8541
# Epoch 43/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1930.5784
# Epoch 44/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2915.9126
# Epoch 45/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1661.6216
# Epoch 46/100
# 378/378 [==============================] - 2s 6ms/step - loss: 20428.5388
# Epoch 47/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1916.4231
# Epoch 48/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1055.3254
# Epoch 49/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1130.8957
# Epoch 50/100
# 378/378 [==============================] - 2s 6ms/step - loss: 963.8178
# Epoch 51/100
# 378/378 [==============================] - 2s 6ms/step - loss: 987.9454
# Epoch 52/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1005.8331
# Epoch 53/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1031.6196
# Epoch 54/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1179.1208
# Epoch 55/100
# 378/378 [==============================] - 2s 6ms/step - loss: 977.0744
# Epoch 56/100
# 378/378 [==============================] - 2s 6ms/step - loss: 945.9514
# Epoch 57/100
# 378/378 [==============================] - 2s 6ms/step - loss: 981.6479
# Epoch 58/100
# 378/378 [==============================] - 2s 6ms/step - loss: 902.7837
# Epoch 59/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1009.4496
# Epoch 60/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1051.2251
# Epoch 61/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1143.6007
# Epoch 62/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1014.6903
# Epoch 63/100
# 378/378 [==============================] - 2s 6ms/step - loss: 942.5897
# Epoch 64/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1066.2165
# Epoch 65/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1059.9288
# Epoch 66/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1252.8148
# Epoch 67/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1263.4303
# Epoch 68/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1144.3646
# Epoch 69/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1193.4003
# Epoch 70/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1225.6954
# Epoch 71/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1062.4816
# Epoch 72/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1115.5874
# Epoch 73/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1452.3796
# Epoch 74/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1157.2693
# Epoch 75/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1806.7984
# Epoch 76/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1368.1989
# Epoch 77/100
# 378/378 [==============================] - 2s 6ms/step - loss: 991.5782
# Epoch 78/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1064.7247
# Epoch 79/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1480.3116
# Epoch 80/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1477.3030
# Epoch 81/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1109.9966
# Epoch 82/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1171.7336
# Epoch 83/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1232.6845
# Epoch 84/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1125.0453
# Epoch 85/100
# 378/378 [==============================] - 2s 6ms/step - loss: 987.4823
# Epoch 86/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1121.4405
# Epoch 87/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1225.4647
# Epoch 88/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1001.5992
# Epoch 89/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1026.5082
# Epoch 90/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1115.0954
# Epoch 91/100
# 378/378 [==============================] - 2s 6ms/step - loss: 927.8673
# Epoch 92/100
# 378/378 [==============================] - 2s 6ms/step - loss: 884.3977
# Epoch 93/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1346.4331
# Epoch 94/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1094.9470
# Epoch 95/100
# 378/378 [==============================] - 2s 6ms/step - loss: 936.4327
# Epoch 96/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1147.1881
# Epoch 97/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1051.0392
# Epoch 98/100
# 378/378 [==============================] - 2s 6ms/step - loss: 2587.1292
# Epoch 99/100
# 378/378 [==============================] - 2s 6ms/step - loss: 983.1827
# Epoch 100/100
# 378/378 [==============================] - 2s 6ms/step - loss: 1083.7587

# %%
preds=model.predict(test_generator)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(preds, close_test_oob[15:])
# Out:
# 53.013451907711215

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [CAD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)

# %%
line_plot(close_test_oob, preds, 'actual', 'prediction', lw=3)

# %%
test_generator_oot = TimeseriesGenerator(close_test_oot, close_test_oot, length=look_back, batch_size=1)

# %%
preds_oot=model.predict(test_generator_oot)

# %%
mean_absolute_error(preds_oot, close_test_oot[15:])
# Out:
# 59.90406465063495

# %%
line_plot(close_test_oot, preds_oot, 'actual', 'prediction', lw=3)

# %%
close_data = close_data.reshape((-1))

def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = dollar_bars.index.values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 500
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)

# %%
oot_forecast=np.concatenate([preds_oot, forecast.reshape(501,1)])

# %%
len(close_test_oot)
# Out:
# 1052

# %%
len(oot_forecast)
# Out:
# 1538

# %%
line_plot(close_test_oot, oot_forecast, 'actual', 'prediction', lw=1)

# %%
dollar_bars.index = pd.to_datetime(dollar_bars.index)

# %%
oot_df = pd.DataFrame({'date': date_test_oot, 'close': close_test_oot.reshape(-1)})

# %%
from datetime import timedelta, date

current_date = dollar_bars.index.max()
future_date = dollar_bars.index.max() + timedelta(days = 10)

start = pd.Timestamp(current_date)
end = pd.Timestamp(future_date)
t = np.linspace(start.value, end.value, 501)
t = pd.to_datetime(t)

# %%
forecast_df =  pd.DataFrame({'date': t, 'close': forecast})

# %%
res_df = pd.concat([oot_df[-100:],forecast_df])

# %%
#res_df.to_csv("/home/ts_model/eth_forecast.csv", index=False)

# %%
from google.cloud import storage
#@bucket_name: nombre del bucket
#@source_path: ruta al archivo local
#@destination_path: nombre del archivo como se va a guardar en bucket
def uploadToBucket(bucket_name, source_path, destination_path):
    try:
        client = storage.Client()
        bucket = client.get_bucket(bucket_name)
        blob = bucket.blob(destination_path)
        blob.upload_from_filename(source_path)

    except Exception as e:
        print("Error {er}".format(str(e)))

# %%
#uploadToBucket('bd_predictions','/home/ts_model/eth_forecast.csv','eth_forecast.csv')
